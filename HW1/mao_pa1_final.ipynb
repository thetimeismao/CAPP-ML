# %% [markdown]
# Andrew Mao
# ML Assignment 1

# %%
import pandas as pd
import pylab
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
# %matplotlib inline

# %%
G_df = pd.read_csv('Graffiti.csv')
P_df = pd.read_csv('Pot_holes.csv')
S_df = pd.read_csv('Sanitation.csv')
V_df = pd.read_csv('VA_Buildings.csv')

# %%
G_df.columns = [x.lower() for x in G_df.columns]
P_df.columns = [x.lower() for x in P_df.columns]
S_df.columns = [x.lower() for x in S_df.columns]
V_df.columns = [x.lower() for x in V_df.columns]

# %%
G_df['type of service request'] = 'Graffiti Removal'
P_df['type of service request'] = 'Pothole'
S_df['type of service request'] = 'Sanitation Code Violation'
V_df['type of service request'] = 'Vacant/Abandoned Bldg'

# %%
V_df = V_df.rename(columns={'date service request was received':'creation date'})
G_df['creation date'] = pd.to_datetime(G_df['creation date'])
P_df['creation date'] = pd.to_datetime(P_df['creation date'])
S_df['creation date'] = pd.to_datetime(S_df['creation date'])
V_df['creation date'] = pd.to_datetime(V_df['creation date'])

# %%
G_df['completion date'] = pd.to_datetime(G_df['completion date'])
P_df['completion date'] = pd.to_datetime(P_df['completion date'])
S_df['completion date'] = pd.to_datetime(S_df['completion date'])

# %%
G_df['response time'] = G_df['completion date'] - G_df['creation date'] 
P_df['response time'] = P_df['completion date'] - P_df['creation date'] 
S_df['response time'] = S_df['completion date'] - S_df['creation date']

# %%
com_df = pd.concat([G_df,P_df,S_df,V_df], axis=0)

# %%
com_counts = com_df['type of service request'].value_counts()

# %%
com_counts.plot.pie(figsize=(6,6))

# %% [markdown]
# The pie chart above contains our first interesting fact!
# 1. Graffiti Removal is this past year's most frequent 311 request with more than the three other types combined. Graffiti is well-acquainted feature of Chicago's most robust neighborhoods, but we can gleam the public desire to remove unwanted public art from this data. As we move down the other types, we nearly fall one-third in frequency at a constant rate until reported vacant and abandoned buildings holding up a sliver. It appears that abandoned buildings are not a generally major hassle for most residents.

# %%
com_bytime = com_df.groupby(pd.Grouper(key='creation date', freq='m')).size()
plt.plot(com_bytime, label='Total')

g_bytime = G_df.groupby(pd.Grouper(key='creation date', freq='m')).size()
plt.plot(g_bytime, label='Graffiti Removal')

p_bytime = P_df.groupby(pd.Grouper(key='creation date', freq='m')).size()
plt.plot(p_bytime, label='Potholes')

s_bytime = S_df.groupby(pd.Grouper(key='creation date', freq='m')).size()
plt.plot(s_bytime, label='Sanitation Code Violation')

v_bytime = V_df.groupby(pd.Grouper(key='creation date', freq='m')).size()
plt.plot(v_bytime, label='Vacant/Abandoned Bldgs')

plt.plot(); plt.legend(loc='best'); plt.show()

# %% [markdown]
# The time series graph above contains our second, third, and fourth interesting facts!
# 2. In summer time leading into September, we can observe a sharp spike in Graffiti (orange) which ultimately contributes most to a similar sharp spike in Total requests (blue). Since the schoolyear begins in September, there could be worthwhile investigations into youth prevalence on streets and graffiti concerns.
# 3. Beginning in the winter leading into February, there is a sharp rise in pot-hole sightings. Winter tends to be the most grueling to overcome degrading potholes, and there could be a relationship between road salt maintenance and road degradation.
# 4. All 311 activity seems to rise minorly in late spring into June. Sanitation code complaints seems to peak in Chicago's hottest weather, nodding to certain health violation signs such as odor.

# %%
com_byneigh = com_df.groupby('community area').size()
plt.plot(com_byneigh, label='Total')

g_byneigh = G_df.groupby('community area').size()
plt.plot(g_byneigh, label='Graffiti Removal')

p_byneigh = P_df.groupby('community area').size()
plt.plot(p_byneigh, label='Potholes')

s_byneigh = S_df.groupby('community area').size()
plt.plot(s_byneigh, label='Sanitation Code Violation')

v_byneigh = V_df.groupby('community area').size()
plt.plot(v_byneigh, label='Vacant/Abandoned Bldgs')

plt.plot(); plt.legend(loc='best'); plt.show()

# %% [markdown]
# The neighborhood-based graph above contains our fifth interesting fact!
# 5. Towards neighborhoods 35-55, there are record lows in 311 requests. This is a likely indication of a different type of residents living in those areas: likely better resources, etc.

# %%
com_byresp = com_df.groupby('response time').size()
plt.plot(com_byresp, label='Total')

g_byresp = G_df.groupby('response time').size()
plt.plot(g_byresp, label='Graffiti')

p_byresp = P_df.groupby('response time').size()
plt.plot(p_byresp, label='Pot-Holes')

s_byresp = S_df.groupby('response time').size()
plt.plot(s_byresp, label='Sanitation')

plt.plot(); plt.legend(loc='best'); plt.show()

# %%
def fcc_api(lat, long):
    '''
    Given a lat/lng coordinate, output a full FIPS id 
    '''
    URL = "http://data.fcc.gov/api/block/find?latitude=" + str(lat) + "&longitude=" + str(long) + "&showall=true"
    r = requests.get(URL)
    tree = ET.fromstring(r.content)
    full_id = tree[0].attrib['FIPS']
    return full_id

# %% [markdown]
# My computer is woefully slow after a few dozen loops.
# I chose to limit my data to 1 month, running on Vacated/Abandoned Buildings and Sanitation Code Complaints.

# %%
v_blocks = []
V1_df = V_df[V_df["creation date"] > '2017-03-05']
for x in V1_df.iterrows():
    lat, long = x[1][20], x[1][21]
    v_blocks.append(fcc_api(lat,long))
# Out:
#   File "<string>", line unknown
# ParseError: mismatched tag: line 1, column 967

# %%
s_blocks = []
S1_df = S_df[S_df["creation date"] > '2017-03-5']
for x in S1_df.iterrows():
    lat, long = x[1][15].strip("(, )").split(', ')
    s_blocks.append(fcc_api(lat,long))
# Out:
# ['170318309001040',
#  '170318322002005',
#  '170318434001004',
#  '170317608032006',
#  '170310207024006',
#  '170310208024004',
#  '170312212002004',
#  '170310307033005',
#  '170311603002004',
#  '170311603002005',
#  '170316201002008',
#  '170312004023004',
#  '170318411001021',
#  '170312222002003',
#  '170310206012002',
#  '170316304003004',
#  '170314309001000',
#  '170315101002054',
#  '170316305003006',
#  '170312511001010',
#  '170315103003013',
#  '170318439001022',
#  '170312520002005',
#  '170314601001001',
#  '170314313012005',
#  '170314305003011',
#  '170312301001014',
#  '170318317001041',
#  '170318391001091',
#  '170311606021000',
#  '170311606021000',
#  '170311606021000',
#  '170311606021000',
#  '170311901001010',
#  '170311408004008',
#  '170318391002044',
#  '170312315006036',
#  '170318396002019',
#  '170318347003014',
#  '170310307033007',
#  '170310307062001',
#  '170318326002005',
#  '170318326002000',
#  '170318326002005',
#  '170315701001028',
#  '170315701001018',
#  '170312216002007',
#  '170318311001001',
#  '170312203001023',
#  '170315702001014',
#  '170315702001014',
#  '170318326002005',
#  '170314313013000',
#  '170318343004021',
#  '170314308001004',
#  '170314203001006',
#  '170318439001019',
#  '170316913002000',
#  '170317506001019',
#  '170317001001000',
#  '170316119001016',
#  '170318360002015',
#  '170316603011021',
#  '170318369002004',
#  '170314409001003',
#  '170316009002016',
#  '170316904002019',
#  '170313818002009',
#  '170312003002012',
#  '170315607002044',
#  '170318412002034',
#  '170310704001012',
#  '170310801002006',
#  '170310703002001',
#  '170311606021000',
#  '170311606021000',
#  '170312206024021',
#  '170310701032000',
#  '170310701032000',
#  '170312434003013',
#  '170315804003016',
#  '170311606021000',
#  '170311407023005',
#  '170310106001009',
#  '170311403023008',
#  '170312434002011',
#  '170312206011003',
#  '170313106003000',
#  '170311202004003',
#  '170311202004003',
#  '170310503002011',
#  '170310101002008',
#  '170315802001027',
#  '170311606021000',
#  '170311002004018',
#  '170314308001004',
#  '170314503002009',
#  '170312004022008',
#  '170312004022009',
#  '170311602004027',
#  '170312305001005',
#  '170314805001017',
#  ...]

# %%
URL_list = []

http://api.census.gov/data/2011/acs5?get=[the data code that you found above]&for=tract:[tract code or *]&in=state:[state code]+county:[county code]&key=[your key]
# Out:
#          service request type service request number creation date  \
# 0   Vacant/Abandoned Building            16-02245017    2016-04-04
# 1   Vacant/Abandoned Building            16-02248875    2016-04-04
# 2   Vacant/Abandoned Building            16-02251252    2016-04-04
# 3   Vacant/Abandoned Building            16-02255526    2016-04-04
# 4   Vacant/Abandoned Building            16-02255561    2016-04-04
# 5   Vacant/Abandoned Building            16-02250794    2016-04-04
# 6   Vacant/Abandoned Building            16-02254820    2016-04-04
# 7   Vacant/Abandoned Building            16-02253011    2016-04-04
# 8   Vacant/Abandoned Building            16-02254420    2016-04-04
# 9   Vacant/Abandoned Building            16-02246712    2016-04-04
# 10  Vacant/Abandoned Building            16-02250520    2016-04-04
# 11  Vacant/Abandoned Building            16-02260838    2016-04-04
# 12  Vacant/Abandoned Building            16-02261517    2016-04-04
# 13  Vacant/Abandoned Building            16-02261545    2016-04-04
# 14  Vacant/Abandoned Building            16-02254711    2016-04-04
# 15  Vacant/Abandoned Building            16-02250140    2016-04-04
# 16  Vacant/Abandoned Building            16-02259866    2016-04-04
# 17  Vacant/Abandoned Building            16-02251413    2016-04-04
# 18  Vacant/Abandoned Building            16-02249405    2016-04-04
# 19  Vacant/Abandoned Building            16-02246605    2016-04-04
#
#    location of building on the lot (if garage, change type code to bgd).  \
# 0                                               Front
# 1                                               Front
# 2                                               Front
# 3                                                Rear
# 4                                              Garage
# 5                                                 NaN
# 6                                                Rear
# 7                                                Rear
# 8                                                Rear
# 9                                                Rear
# 10                                              Front
# 11                                              Front
# 12                                              Front
# 13                                              Front
# 14                                              Front
# 15                                              Front
# 16                                              Front
# 17                                              Front
# 18                                               Rear
# 19                                               Rear
#
#     is the building dangerous or hazardous? is building open or boarded?  \
# 0                                       NaN                         Open
# 1                                       NaN                         Open
# 2                                       NaN                         Open
# 3                                       NaN                      Boarded
# 4                                       NaN                         Open
# 5                                       NaN                          NaN
# 6                                       NaN                      Boarded
# 7                                       NaN                         Open
# 8                                       NaN                      Boarded
# 9                                       NaN                         Open
# 10                                      NaN                      Boarded
# 11                                      NaN                         Open
# 12                                      NaN                         Open
# 13                                      NaN                         Open
# 14                                      NaN                         Open
# 15                                      NaN                         Open
# 16                                      NaN                      Boarded
# 17                                      NaN                         Open
# 18                                      NaN                         Open
# 19                                      NaN                         Open
#
#    if the building is open, where is the entry point?  \
# 0                                               FRONT
# 1     FRONT DOOR WIDE OPEN/GARAGE SIDE DOOR WIDE OPEN
# 2                                                 NaN
# 3                                                 NaN
# 4                       FRONT DOOR HOUSE/GARAGE DOORS
# 5                                                 NaN
# 6                                HOLE IN REAR OF BLDG
# 7                                                 NaN
# 8                                                 NaN
# 9                                          FRONT DOOR
# 10                                                NaN
# 11                                         FRONT/REAR
# 12                                                NaN
# 13                                                NaN
# 14                            THE FRONT AND BACK DOOR
# 15                                                NaN
# 16                                                NaN
# 17                                              FRONT
# 18                                               REAR
# 19                                               REAR
#
#    is the building currently vacant or occupied?  \
# 0                                         Vacant
# 1                                         Vacant
# 2                                         Vacant
# 3                                         Vacant
# 4                                         Vacant
# 5                                            NaN
# 6                                         Vacant
# 7                                         Vacant
# 8                                         Vacant
# 9                                         Vacant
# 10                                        Vacant
# 11                                        Vacant
# 12                                        Vacant
# 13                                        Vacant
# 14                                        Vacant
# 15                                        Vacant
# 16                                        Vacant
# 17                                      Occupied
# 18                                        Vacant
# 19                                        Vacant
#
#    is the building vacant due to fire?  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# 5                                  NaN
# 6                                False
# 7                                False
# 8                                False
# 9                                False
# 10                               False
# 11                               False
# 12                               False
# 13                               False
# 14                               False
# 15                               False
# 16                               False
# 17                                True
# 18                               False
# 19                               False
#
#    any people using property? (homeless, childen, gangs)  \
# 0                                               False
# 1                                                True
# 2                                               False
# 3                                                True
# 4                                                True
# 5                                                 NaN
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                               True
# 13                                               True
# 14                                               True
# 15                                               True
# 16                                              False
# 17                                               True
# 18                                              False
# 19                                              False
#
#     address street number address street direction       address street name  \
# 0                     131                        E                     103RD
# 1                    7933                        S                     DANTE
# 2                     733                        E                     134TH
# 3                    7848                        S                   KIMBARK
# 4                    7531                        S                    COLFAX
# 5                    1445                        E                      67TH
# 6                    8005                        S  DR MARTIN LUTHER KING JR
# 7                    7842                        S                    COLFAX
# 8                    6004                        S                 FAIRFIELD
# 9                    1222                        W                      72ND
# 10                   6004                        S                  ABERDEEN
# 11                   4434                        W                    MONROE
# 12                  12221                        S                    PEORIA
# 13                  12230                        S                  ABERDEEN
# 14                   6620                        S                    RHODES
# 15                   2845                        W                      51ST
# 16                   1446                        N                 MILWAUKEE
# 17                   1029                        W                     103RD
# 18                    434                        W                     102ND
# 19                   4409                        S                    NORMAL
#
#    address street suffix  zip code  x coordinate  y coordinate  ward  \
# 0                     PL     60628  1.179085e+06  1.836380e+06     9
# 1                    AVE     60619  1.187230e+06  1.852675e+06     8
# 2                     PL     60827  1.183655e+06  1.816170e+06     9
# 3                    AVE     60619  1.186241e+06  1.853217e+06     8
# 4                    AVE     60649  1.194820e+06  1.855526e+06     7
# 5                     PL     60637  1.187003e+06  1.860525e+06     5
# 6                     DR     60619  1.180290e+06  1.852017e+06     6
# 7                    AVE     60649  1.194880e+06  1.853471e+06     7
# 8                    AVE     60629  1.159072e+06  1.864724e+06    16
# 9                     PL     60636  1.169380e+06  1.856709e+06     6
# 10                    ST     60621  1.170010e+06  1.864990e+06    16
# 11                    ST     60624  1.146841e+06  1.899294e+06    28
# 12                    ST     60643  1.172539e+06  1.823798e+06    34
# 13                    ST     60643  1.171210e+06  1.823702e+06    34
# 14                   AVE     60637  1.181040e+06  1.861239e+06    20
# 15                    ST     60632  1.158079e+06  1.870704e+06    14
# 16                   AVE     60622  1.163758e+06  1.909784e+06     1
# 17                    PL     60643  1.171284e+06  1.836186e+06    34
# 18                    PL     60628  1.175129e+06  1.836946e+06     9
# 19                   AVE     60609  1.173700e+06  1.875662e+06    11
#
#     police district  community area   latitude  longitude  \
# 0                 5              49  41.706316 -87.619810
# 1                 4              45  41.750841 -87.589465
# 2                 5              54  41.650752 -87.603700
# 3                 4              45  41.752351 -87.593075
# 4                 4              43  41.758482 -87.561560
# 5                 3              43  41.772387 -87.590051
# 6                 6              44  41.749199 -87.614918
# 7                 4              43  41.752840 -87.561406
# 8                 8              66  41.784528 -87.692322
# 9                 7              67  41.762317 -87.654761
# 10                7              68  41.785026 -87.652211
# 11               11              26  41.879635 -87.736285
# 12                5              53  41.671934 -87.644150
# 13                5              53  41.671699 -87.649016
# 14                3              42  41.774486 -87.611886
# 15                9              63  41.800958 -87.695799
# 16               14              24  41.908080 -87.673874
# 17               22              73  41.705956 -87.648380
# 18               22              73  41.707957 -87.634279
# 19                9              61  41.814232 -87.638367
#
#                                     location type of service request
# 0   (41.706316349642435, -87.61980966474108)   Vacant/Abandoned Bldg
# 1      (41.7508413687313, -87.5894654145728)   Vacant/Abandoned Bldg
# 2    (41.65075158509962, -87.60369974504695)   Vacant/Abandoned Bldg
# 3    (41.752351369868464, -87.5930745568237)   Vacant/Abandoned Bldg
# 4   (41.758481656983264, -87.56155969009926)   Vacant/Abandoned Bldg
# 5      (41.7723869206673, -87.5900507563601)   Vacant/Abandoned Bldg
# 6    (41.74919859596181, -87.61491769547918)   Vacant/Abandoned Bldg
# 7   (41.752839638861346, -87.56140586219601)   Vacant/Abandoned Bldg
# 8    (41.78452807455499, -87.69232183549155)   Vacant/Abandoned Bldg
# 9   (41.762316791460755, -87.65476135743857)   Vacant/Abandoned Bldg
# 10    (41.7850258581814, -87.65221091080815)   Vacant/Abandoned Bldg
# 11  (41.879634630761124, -87.73628471289257)   Vacant/Abandoned Bldg
# 12    (41.67193392367753, -87.6441496923775)   Vacant/Abandoned Bldg
# 13  (41.671698865644665, -87.64901627910582)   Vacant/Abandoned Bldg
# 14   (41.774485510732916, -87.6118857860719)   Vacant/Abandoned Bldg
# 15  (41.800958239262506, -87.69579875571246)   Vacant/Abandoned Bldg
# 16    (41.90808016755403, -87.6738742307312)   Vacant/Abandoned Bldg
# 17   (41.70595620757477, -87.64838018060806)   Vacant/Abandoned Bldg
# 18   (41.70795717117498, -87.63427895012359)   Vacant/Abandoned Bldg
# 19   (41.81423156881744, -87.63836698461917)   Vacant/Abandoned Bldg

# %%
def census_api(add_data, tract, state, county, key):
    '''
    Given api parameters, returns query output from census api
    '''
    URL = 'http://api.census.gov/data/2015/acs5?get=' + str(add_data) + '&for=tract:' + str(tract) + '&in=state:' + str(state) + '+county:' + str(county) + '&key=' + str(key)
    r = requests.get(URL)
    return r

# %%
# Chinese, Median Income, Median Age
add_data = 'B02015_007E,B06011_001E,B01002_001E'

key = 'ddc73208b194992eb71bc5e3c564347e414f2d62'
IL = '17'
Cook = '031'

# %%
s_newdata = []

for fips in s_blocks:
    s_newdata.append(census_api(add_data,fips[5:11],IL,Cook,key))

# %%
v_newdata = []

for fips in v_blocks:
    v_newdata.append(census_api(add_data,fips[5:11],IL,Cook,key))

# %%
chinese = []
income = []
age = []

for x in s_newdata:
    data = x.json()
    chinese.append(data[1][0])
    income.append(data[1][1])
    age.append(data[1][2])

Snew_df = S1_df
Snew_df["Chinese"] = chinese
Snew_df["Median Income"] = income
Snew_df["Median Age"] = age
# Out:
# C:\Users\Andrew Mao\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Andrew Mao\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Andrew Mao\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
s_bynewdata = Snew_df.groupby('Median Income').size()
plt.plot(s_bynewdata, label='Sanitation Code Violation')

#v_bynewdata = Vnew_df.groupby('Median Income').size()
#plt.plot(v_bynewdata, label='Vacant/Abandoned Bldgs')

plt.plot(); plt.legend(loc='best'); plt.show()

# %% [markdown]
# The above graph shows concentation of sanitation violations across different blocks, each with a median income. It's a clear enough relationship between lower income and higher frequency of reported sanitation code violations. Interesting to also note a gradual hump and spike in the $40K 'middle class' category as well; this could be due to the American middle class vulnerability to poor conditions as well.

# %%
s_bynewdata = Snew_df.groupby('Median Age').size()
plt.plot(s_bynewdata, label='Sanitation Code Violation')

#v_bynewdata = Vnew_df.groupby('Median Income').size()
#plt.plot(v_bynewdata, label='Vacant/Abandoned Bldgs')

plt.plot(); plt.legend(loc='best'); plt.show()

# %% [markdown]
# The above graph shows concentation of sanitation violations across different blocks, each with a median age. The roughly parabolic relationship of age and sanitation code violations centering around 33 is interesting to note, especially since there is a noticeable dip in the later 30s which spikes right around 40 years old.

# %%
s_bynewdata = Snew_df.groupby('Chinese').size()
plt.plot(s_bynewdata, label='Sanitation Code Complaints')

#v_bynewdata = Vnew_df.groupby('Median Income').size()
#plt.plot(v_bynewdata, label='Vacant/Abandoned Bldgs')

plt.plot(); plt.legend(loc='best'); plt.show()

# %% [markdown]
# We can't observe much of a relationship between Chinese populations and sanitation code complaints. There is a little bit of activity closer towards lower populations, so it's possible larger Chinese populations are related to fewer sanitation complaints.

# %%
chinese = []
income = []
age = []

for x in v_newdata:
    data = x.json()
    chinese.append(data[1][0])
    income.append(data[1][1])
    age.append(data[1][2])

Vnew_df = V1_df
print(len(chinese))
print(len(Vnew_df))
#Vnew_df["Chinese"] = chinese
#Vnew_df["Median Income"] = income
#Vnew_df["Median Age"] = age
# Out:
# 121
# 453

# %% [markdown]
# Above, the length of my new data is not equal to the length of my 1 month dataframe of original data. This is due to an error in the API. I apologize for not being able to compare Vacant/Abandoned buildings.

# %%
# Originally intended to utilize tracts through this csv
Chicago_tracts = pd.read_csv('CensusTractsTIGER2010.csv')
tract_num = Chicago_tracts['TRACTCE10']
type(tract_num)
print(tract_num[0])
# Out:
# 842400

# %% [markdown]
#     Problem 3 A
# 7500 S Wolcott Ave has a lat/long coordinate of [41.757380,-87.671264]. We can average lat/long over all four databases and find out which type of 311 call is more similar to the Wolcott address. Vacant/Abandoned Buildings is most likely.

# %%
v = ["Vacant/Abandoned Buildings",V_df["latitude"].mean(), V_df["longitude"].mean()]
p = ["Potholes",P_df["latitude"].mean(), P_df["longitude"].mean()]
g = ["Sanitation Code Complaints",G_df["latitude"].mean(), G_df["longitude"].mean()]
s = ["Graffiti",S_df["latitude"].mean(), S_df["longitude"].mean()]

for x in [v,g,s,p]:
    lat_diff,lon_diff = x[1] - 41.757380, x[2] + 87.671264
    print(x[0],lat_diff + lon_diff)
# Out:
# Vacant/Abandoned Buildings 0.04015364435992552
# Sanitation Code Complaints 0.10582810415051824
# Graffiti 0.08269126611099864
# Potholes 0.08434180596286467

# %% [markdown]
#     Problem 3 B
# Assuming South Lawndale, its coordinates are 41.845816,-87.705823. Uptown Chicago has coordinates 41.96654, -87.65334. We can average Graffiti lat/long and find out which neighborhood is closer. Lawndale is closer.

# %%
g = [G_df["latitude"].mean(), G_df["longitude"].mean()]

Lawndale = ["Lawndale",41.845816,-87.705823]
Uptown = ["Update", 41.96654, -87.65334]

for x in [Lawndale,Uptown]:
    lat_diff,lon_diff = x[1] - g[0], x[2] - g[1]
    print(x[0],lat_diff + lon_diff)
# Out:
# Lawndale -0.05195110415051829
# Update 0.1212558958494796

# %% [markdown]
#     Problem 3 C
# To solve this problem, we are going to subtract P(Englewood|Graffiti) - P(Uptown|Graffiti). This equation expands to P(Englewood and Graffiti)/P(Graffiti) - P(Uptown and Graffiti)/P(Graffiti).
#
# This further expands to P(Graffiti | Englewood)* P(Englewood)/P(Graffiti) - P(Graffiti|Uptown)*P(Uptown)/P(Graffiti).
#
# Substituting numbers: (100/600)(600/1000)/(260/1000) - (160/400)(400/1000)/(260/1000) = -0.230769231
#
# Therefore, it's 23% less likely that the call came from Englewood versus Uptown.
